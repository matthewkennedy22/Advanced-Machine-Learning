# %% [markdown]
# # RNN Day 1 Housing Data

# %% [markdown]
# ### Importing Libraries

# %%
import os
from pathlib import Path

import pandas as pd                                 # table/dataframe handling
import numpy as np                                  # numerical operations
import matplotlib.pyplot as plt                     # plotting

from sklearn.preprocessing import MinMaxScaler      # scales values to 0-1 range
from sklearn.metrics import mean_absolute_error, mean_squared_error 
                                                    # RMSE and MAE calculation

import tensorflow as tf
import random

from tensorflow.keras.models import Sequential      # sequential neural network API

from tensorflow.keras.layers import (
    Dense,                                          # standard fully connected layer
    SimpleRNN,                                      # recurrent neural network layer
    Conv1D,                                         # 1D convolution layer
    Flatten,                                        # flatten multidimensional output
    Dropout,                                        # regularization for experiments
)

# Run from Week 9 so ma_lga_12345.csv resolves
for candidate in [Path.cwd(), Path.cwd() / "Week 9"]:
    if (candidate / "ma_lga_12345.csv").is_file():
        os.chdir(candidate)
        break
else:
    week9 = Path("/Users/mkenne16/Documents/Advanced Machine Learning/Week 9")
    if (week9 / "ma_lga_12345.csv").is_file():
        os.chdir(week9)

DATA_FILE = Path("ma_lga_12345.csv")
assert DATA_FILE.is_file(), f"Missing {DATA_FILE}. Place ma_lga_12345.csv in Week 9."
print("Working directory:", Path.cwd())

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# Working directory: /Users/mkenne16/Documents/Advanced Machine Learning/Week 9

# %% [markdown]
# ### Loading the data

# %%
house = pd.read_csv(DATA_FILE)              # load housing dataset

house.head()                              # inspect first few rows
# Out:
#      saledate      MA   type  bedrooms
# 0  30/09/2007  441854  house         2
# 1  31/12/2007  441854  house         2
# 2  31/03/2008  441854  house         2
# 3  30/06/2008  441854  house         2
# 4  30/09/2008  451583  house         2

# %% [markdown]
# ### Inspecting the temporal nature of the data

# %%
print(house.shape)            # number of rows and columns
print(house.dtypes)           # variable data types
print(house.isna().sum())     # missing values per column

house.describe()              # summary statistics
# Out:
# (347, 4)
# saledate      str
# MA          int64
# type          str
# bedrooms    int64
# dtype: object
# saledate    0
# MA          0
# type        0
# bedrooms    0
# dtype: int64
#                  MA    bedrooms
# count  3.470000e+02  347.000000
# mean   5.481320e+05    2.867435
# std    1.701934e+05    1.239875
# min    3.167510e+05    1.000000
# 25%    4.277395e+05    2.000000
# 50%    5.077440e+05    3.000000
# 75%    6.275155e+05    4.000000
# max    1.017752e+06    5.000000

# %% [markdown]
# ## Defining useful functions

# %% [markdown]
# Formatting data for rolling windows

# %%
def create_sequences(dataset, look_back=2):

    X, y = [], []                          # containers for windows and targets

    for i in range(len(dataset) - look_back):

        X.append(dataset[i:i + look_back, :])   # rolling window
        y.append(dataset[i + look_back, 0])     # next timestep target

    return np.array(X), np.array(y)

# %% [markdown]
# Plotting training curves

# %%
def plot_training_curves(history, title):

    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].plot(history.history["loss"], label="Training Loss")
    axes[0].plot(history.history["val_loss"], label="Validation Loss")
    axes[0].set_title(title + " Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("MSE Loss")
    axes[0].set_ylim(0, 0.4)
    axes[0].legend()

    axes[1].plot(history.history["mean_absolute_error"], label="Training MAE")
    axes[1].plot(history.history["val_mean_absolute_error"], label="Validation MAE")
    axes[1].set_title(title + " MAE")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Mean Absolute Error")
    axes[1].set_ylim(0, 0.65)
    axes[1].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Evaluating model performance on test data

# %%
def evaluate_and_plot(model, trainX, testX, trainY, testY, scaler, title):

    # Make predictions
    train_pred = model.predict(trainX)
    test_pred = model.predict(testX)

    # Convert scaled values back to original MA scale
    train_pred_inv = scaler.inverse_transform(train_pred)
    test_pred_inv = scaler.inverse_transform(test_pred)
    trainY_inv = scaler.inverse_transform(trainY.reshape(-1, 1))
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    # Calculate RMSE on original scale
    train_rmse = np.sqrt(mean_squared_error(trainY_inv, train_pred_inv))
    test_rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))

    print(f"{title} Train RMSE: {train_rmse:.2f}")
    print(f"{title} Test RMSE: {test_rmse:.2f}")

    # Plot held-out future test predictions
    plt.figure(figsize=(10, 4))
    plt.plot(testY_inv, label="Actual")
    plt.plot(test_pred_inv, label="Predicted")

    plt.title(title + " Test Predictions")
    plt.xlabel("Test time index")
    plt.ylabel("MA")
    plt.ylim(0, 1200000)
    plt.ticklabel_format(style="plain", axis="y")
    plt.legend()
    plt.show()

# %% [markdown]
# Comparing forcasting performance metrics

# %%
def evaluate_metrics(model, testX, testY, scaler):

    test_pred = model.predict(testX)

    test_pred_inv = scaler.inverse_transform(test_pred)
    testY_inv = scaler.inverse_transform(testY.reshape(-1, 1))

    rmse = np.sqrt(mean_squared_error(testY_inv, test_pred_inv))
    mae = mean_absolute_error(testY_inv, test_pred_inv)

    return rmse, mae

# %% [markdown]
# ### Initial RNN & Performance

# %%
# Initial RNN

ma_sequence = house.copy()
ma_sequence = ma_sequence.sort_values("saledate").reset_index(drop=True)
                                                                # preserve chronological order

df_initial = ma_sequence[["MA"]].copy()                         # univariate forecasting feature

scaler_initial = MinMaxScaler(feature_range=(0, 1))
scaled_initial = scaler_initial.fit_transform(df_initial)
                                                                # neural networks train better on scaled values

look_back = 2                                                   # use previous 2 timesteps to predict next timestep

train_size = int(len(scaled_initial) * 0.8)

train_initial = scaled_initial[:train_size]                     # earlier historical data
test_initial = scaled_initial[train_size:]                      # held-out future data

trainX_initial, trainY_initial = create_sequences(
    train_initial,
    look_back
)                                                               # rolling training windows

testX_initial, testY_initial = create_sequences(
    test_initial,
    look_back
)                                                               # rolling future test windows

print("trainX shape:", trainX_initial.shape)
print("testX shape:", testX_initial.shape)

initial_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_initial.shape[2])
    ),                                                          # recurrent hidden layer

    Dense(1)                                                    # regression output layer
])

initial_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

initial_history = initial_model.fit(
    trainX_initial,
    trainY_initial,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                                              # preserve temporal order
    verbose=1
)
# Out:
# trainX shape: (275, 2, 1)
# testX shape: (68, 2, 1)
# Epoch 1/100
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0837 - mean_absolute_error: 0.2303 - val_loss: 0.0884 - val_mean_absolute_error: 0.2418
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0671 - mean_absolute_error: 0.2065 - val_loss: 0.0744 - val_mean_absolute_error: 0.2194
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0588 - mean_absolute_error: 0.1904 - val_loss: 0.0669 - val_mean_absolute_error: 0.2029
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0547 - mean_absolute_error: 0.1817 - val_loss: 0.0631 - val_mean_absolute_error: 0.1940
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0528 - mean_absolute_error: 0.1778 - val_loss: 0.0613 - val_mean_absolute_error: 0.1888
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0518 - mean_absolute_error: 0.1758 - val_loss: 0.0604 - val_mean_absolute_error: 0.1859
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0513 - mean_absolute_error: 0.1746 - val_loss: 0.0600 - val_mean_absolute_error: 0.1844
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0510 - mean_absolute_error: 0.1738 - val_loss: 0.0598 - val_mean_absolute_error: 0.1836
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0508 - mean_absolute_error: 0.1733 - val_loss: 0.0596 - val_mean_absolute_error: 0.1830
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0507 - mean_absolute_error: 0.1729 - val_loss: 0.0595 - val_mean_absolute_error: 0.1826
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0506 - mean_absolute_error: 0.1725 - val_loss: 0.0595 - val_mean_absolute_error: 0.1823
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0505 - mean_absolute_error: 0.1722 - val_loss: 0.0594 - val_mean_absolute_error: 0.1821
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0504 - mean_absolute_error: 0.1720 - val_loss: 0.0594 - val_mean_absolute_error: 0.1819
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0503 - mean_absolute_error: 0.1718 - val_loss: 0.0593 - val_mean_absolute_error: 0.1818
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1716 - val_loss: 0.0593 - val_mean_absolute_error: 0.1816
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501 - mean_absolute_error: 0.1714 - val_loss: 0.0592 - val_mean_absolute_error: 0.1815
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501 - mean_absolute_error: 0.1713 - val_loss: 0.0592 - val_mean_absolute_error: 0.1813
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1711 - val_loss: 0.0592 - val_mean_absolute_error: 0.1812
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1710 - val_loss: 0.0591 - val_mean_absolute_error: 0.1811
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0499 - mean_absolute_error: 0.1709 - val_loss: 0.0591 - val_mean_absolute_error: 0.1810
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0499 - mean_absolute_error: 0.1707 - val_loss: 0.0590 - val_mean_absolute_error: 0.1809
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0498 - mean_absolute_error: 0.1706 - val_loss: 0.0590 - val_mean_absolute_error: 0.1807
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0497 - mean_absolute_error: 0.1705 - val_loss: 0.0589 - val_mean_absolute_error: 0.1806
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0497 - mean_absolute_error: 0.1704 - val_loss: 0.0589 - val_mean_absolute_error: 0.1805
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mean_absolute_error: 0.1703 - val_loss: 0.0588 - val_mean_absolute_error: 0.1804
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mean_absolute_error: 0.1702 - val_loss: 0.0588 - val_mean_absolute_error: 0.1803
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0495 - mean_absolute_error: 0.1701 - val_loss: 0.0587 - val_mean_absolute_error: 0.1802
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0495 - mean_absolute_error: 0.1700 - val_loss: 0.0587 - val_mean_absolute_error: 0.1801
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0495 - mean_absolute_error: 0.1699 - val_loss: 0.0586 - val_mean_absolute_error: 0.1801
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0494 - mean_absolute_error: 0.1698 - val_loss: 0.0586 - val_mean_absolute_error: 0.1800
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - mean_absolute_error: 0.1697 - val_loss: 0.0585 - val_mean_absolute_error: 0.1799
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mean_absolute_error: 0.1696 - val_loss: 0.0584 - val_mean_absolute_error: 0.1798
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0493 - mean_absolute_error: 0.1695 - val_loss: 0.0584 - val_mean_absolute_error: 0.1797
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0492 - mean_absolute_error: 0.1694 - val_loss: 0.0583 - val_mean_absolute_error: 0.1796
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1693 - val_loss: 0.0582 - val_mean_absolute_error: 0.1795
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mean_absolute_error: 0.1692 - val_loss: 0.0582 - val_mean_absolute_error: 0.1794
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0491 - mean_absolute_error: 0.1691 - val_loss: 0.0581 - val_mean_absolute_error: 0.1793
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0490 - mean_absolute_error: 0.1690 - val_loss: 0.0581 - val_mean_absolute_error: 0.1792
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mean_absolute_error: 0.1689 - val_loss: 0.0580 - val_mean_absolute_error: 0.1790
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0489 - mean_absolute_error: 0.1689 - val_loss: 0.0579 - val_mean_absolute_error: 0.1789
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1688 - val_loss: 0.0578 - val_mean_absolute_error: 0.1788
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1687 - val_loss: 0.0578 - val_mean_absolute_error: 0.1787
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487 - mean_absolute_error: 0.1686 - val_loss: 0.0577 - val_mean_absolute_error: 0.1786
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0487 - mean_absolute_error: 0.1685 - val_loss: 0.0576 - val_mean_absolute_error: 0.1785
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1684 - val_loss: 0.0575 - val_mean_absolute_error: 0.1784
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1683 - val_loss: 0.0575 - val_mean_absolute_error: 0.1783
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - mean_absolute_error: 0.1682 - val_loss: 0.0574 - val_mean_absolute_error: 0.1782
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1681 - val_loss: 0.0573 - val_mean_absolute_error: 0.1781
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1680 - val_loss: 0.0572 - val_mean_absolute_error: 0.1780
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483 - mean_absolute_error: 0.1679 - val_loss: 0.0571 - val_mean_absolute_error: 0.1779
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483 - mean_absolute_error: 0.1678 - val_loss: 0.0571 - val_mean_absolute_error: 0.1778
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0482 - mean_absolute_error: 0.1677 - val_loss: 0.0570 - val_mean_absolute_error: 0.1777
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1676 - val_loss: 0.0569 - val_mean_absolute_error: 0.1776
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1675 - val_loss: 0.0568 - val_mean_absolute_error: 0.1774
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0480 - mean_absolute_error: 0.1674 - val_loss: 0.0567 - val_mean_absolute_error: 0.1774
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0480 - mean_absolute_error: 0.1673 - val_loss: 0.0566 - val_mean_absolute_error: 0.1773
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1671 - val_loss: 0.0565 - val_mean_absolute_error: 0.1772
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0478 - mean_absolute_error: 0.1670 - val_loss: 0.0564 - val_mean_absolute_error: 0.1771
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0478 - mean_absolute_error: 0.1669 - val_loss: 0.0564 - val_mean_absolute_error: 0.1770
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0477 - mean_absolute_error: 0.1668 - val_loss: 0.0563 - val_mean_absolute_error: 0.1769
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0476 - mean_absolute_error: 0.1667 - val_loss: 0.0562 - val_mean_absolute_error: 0.1769
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0476 - mean_absolute_error: 0.1666 - val_loss: 0.0561 - val_mean_absolute_error: 0.1768
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0475 - mean_absolute_error: 0.1665 - val_loss: 0.0560 - val_mean_absolute_error: 0.1767
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0474 - mean_absolute_error: 0.1664 - val_loss: 0.0559 - val_mean_absolute_error: 0.1766
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0474 - mean_absolute_error: 0.1662 - val_loss: 0.0558 - val_mean_absolute_error: 0.1765
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0473 - mean_absolute_error: 0.1661 - val_loss: 0.0557 - val_mean_absolute_error: 0.1765
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0472 - mean_absolute_error: 0.1660 - val_loss: 0.0556 - val_mean_absolute_error: 0.1764
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0472 - mean_absolute_error: 0.1659 - val_loss: 0.0555 - val_mean_absolute_error: 0.1763
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0471 - mean_absolute_error: 0.1658 - val_loss: 0.0554 - val_mean_absolute_error: 0.1762
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0471 - mean_absolute_error: 0.1657 - val_loss: 0.0553 - val_mean_absolute_error: 0.1762
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - mean_absolute_error: 0.1655 - val_loss: 0.0552 - val_mean_absolute_error: 0.1761
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0469 - mean_absolute_error: 0.1654 - val_loss: 0.0551 - val_mean_absolute_error: 0.1760
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0469 - mean_absolute_error: 0.1653 - val_loss: 0.0550 - val_mean_absolute_error: 0.1759
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0468 - mean_absolute_error: 0.1652 - val_loss: 0.0550 - val_mean_absolute_error: 0.1759
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0467 - mean_absolute_error: 0.1651 - val_loss: 0.0549 - val_mean_absolute_error: 0.1758
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0467 - mean_absolute_error: 0.1649 - val_loss: 0.0548 - val_mean_absolute_error: 0.1757
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - mean_absolute_error: 0.1648 - val_loss: 0.0547 - val_mean_absolute_error: 0.1756
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - mean_absolute_error: 0.1647 - val_loss: 0.0546 - val_mean_absolute_error: 0.1755
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0465 - mean_absolute_error: 0.1646 - val_loss: 0.0545 - val_mean_absolute_error: 0.1754
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464 - mean_absolute_error: 0.1645 - val_loss: 0.0544 - val_mean_absolute_error: 0.1754
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0464 - mean_absolute_error: 0.1644 - val_loss: 0.0543 - val_mean_absolute_error: 0.1753
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1643 - val_loss: 0.0543 - val_mean_absolute_error: 0.1752
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0463 - mean_absolute_error: 0.1642 - val_loss: 0.0542 - val_mean_absolute_error: 0.1751
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1640 - val_loss: 0.0541 - val_mean_absolute_error: 0.1750
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462 - mean_absolute_error: 0.1639 - val_loss: 0.0540 - val_mean_absolute_error: 0.1749
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1638 - val_loss: 0.0539 - val_mean_absolute_error: 0.1748
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1637 - val_loss: 0.0539 - val_mean_absolute_error: 0.1747
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460 - mean_absolute_error: 0.1636 - val_loss: 0.0538 - val_mean_absolute_error: 0.1746
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460 - mean_absolute_error: 0.1635 - val_loss: 0.0537 - val_mean_absolute_error: 0.1745
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0459 - mean_absolute_error: 0.1634 - val_loss: 0.0537 - val_mean_absolute_error: 0.1744
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0459 - mean_absolute_error: 0.1633 - val_loss: 0.0536 - val_mean_absolute_error: 0.1743
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458 - mean_absolute_error: 0.1632 - val_loss: 0.0535 - val_mean_absolute_error: 0.1742
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458 - mean_absolute_error: 0.1632 - val_loss: 0.0535 - val_mean_absolute_error: 0.1741
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0457 - mean_absolute_error: 0.1631 - val_loss: 0.0534 - val_mean_absolute_error: 0.1740
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0457 - mean_absolute_error: 0.1630 - val_loss: 0.0533 - val_mean_absolute_error: 0.1739
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0456 - mean_absolute_error: 0.1630 - val_loss: 0.0533 - val_mean_absolute_error: 0.1738
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0456 - mean_absolute_error: 0.1629 - val_loss: 0.0532 - val_mean_absolute_error: 0.1737
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0456 - mean_absolute_error: 0.1628 - val_loss: 0.0531 - val_mean_absolute_error: 0.1736
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0455 - mean_absolute_error: 0.1628 - val_loss: 0.0531 - val_mean_absolute_error: 0.1734
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455 - mean_absolute_error: 0.1627 - val_loss: 0.0530 - val_mean_absolute_error: 0.1733

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    initial_history,
    "Initial RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    initial_model,
    trainX_initial,
    testX_initial,
    trainY_initial,
    testY_initial,
    scaler_initial,
    "Initial RNN"
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Initial RNN Train RMSE: 150505.92
# Initial RNN Test RMSE: 150254.06

# %% [markdown]
# ### Initial MA data re-evaluation

# %%
# Plot the original MA sequence exactly as provided

plt.figure(figsize=(10, 4))

plt.plot(
    ma_sequence["saledate"],
    ma_sequence["MA"]
)

plt.title("Original MA sequence")
plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)                                        

plt.xticks(rotation=45)

plt.show()

# %%
# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

# Plot each subgroup MA sequence separately

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)

plt.figure(figsize=(12, 6))

for (property_type, bedrooms), group in house.groupby(["type", "bedrooms"]):

    group = group.sort_values("saledate")      # chronological ordering

    plt.plot(
        group["saledate"],
        group["MA"],
        label=f"{property_type}, {bedrooms} bed"
    )

plt.title("MA sequences by property subgroup")

plt.xlabel("Date")
plt.ylabel("MA")

plt.ylim(0, 1200000)

plt.ticklabel_format(
    style='plain',
    axis='y'
)

plt.xticks(rotation=45)

plt.legend(
    bbox_to_anchor=(1.05, 1),
    loc="upper left"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# Inspecting the first window

# %%
print("trainX_initial shape:", trainX_initial.shape)

window_id = 0

ma_sequence.iloc[
    window_id : window_id + look_back + 1
][["saledate", "type", "bedrooms", "MA"]]
# Out:
# trainX_initial shape: (275, 2, 1)
#      saledate   type  bedrooms      MA
# 0  30/06/2007  house         3  421291
# 1  30/06/2007  house         4  548969
# 2  30/06/2007   unit         2  368817

# %% [markdown]
# ### Creating market-level MA data

# %%
# Create market-level MA sequence

house["saledate"] = pd.to_datetime(
    house["saledate"],
    dayfirst=True
)                                                    # ensure dates sort chronologically

market_ma = (
    house
    .groupby("saledate")["MA"]
    .mean()
    .reset_index()
    .sort_values("saledate")
    .reset_index(drop=True)
)                                                    # average subgroup MAs per date

# Visualize market-level MA

plt.figure(figsize=(10, 4))

plt.plot(
    market_ma["saledate"],
    market_ma["MA"]
)

plt.title("Market-level MA: one average value per date")
plt.xlabel("Date")
plt.ylabel("Average MA")

plt.ylim(0, 1200000)
plt.ticklabel_format(style="plain", axis="y")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Preparing market-level MA data for variety of models

# %%
# Prepare market-level MA data for all fixed-data models

df_market = market_ma[["MA"]].copy()                            # cleaned one-value-per-date MA series

scaler_market = MinMaxScaler(feature_range=(0, 1))              # scale MA values for neural networks
scaled_market = scaler_market.fit_transform(df_market)

look_back = 2                                                   # use 2 previous timesteps to predict next timestep

train_size = int(len(scaled_market) * 0.8)                      # chronological 80/20 split

train_market = scaled_market[:train_size]                       # earlier historical data
test_market = scaled_market[train_size:]                        # held-out future data

trainX_market, trainY_market = create_sequences(
    train_market,
    look_back
)                                                               # sequence windows for RNN/CNN

testX_market, testY_market = create_sequences(
    test_market,
    look_back
)                                                               # future test windows for RNN/CNN

trainX_market_mlp = trainX_market.reshape(
    trainX_market.shape[0],
    trainX_market.shape[1] * trainX_market.shape[2]
)                                                               # flattened windows for MLP

testX_market_mlp = testX_market.reshape(
    testX_market.shape[0],
    testX_market.shape[1] * testX_market.shape[2]
)                                                               # flattened test windows for MLP

print("RNN/CNN trainX_market shape:", trainX_market.shape)
print("RNN/CNN testX_market shape:", testX_market.shape)

print("MLP trainX_market_mlp shape:", trainX_market_mlp.shape)
print("MLP testX_market_mlp shape:", testX_market_mlp.shape)
# Out:
# RNN/CNN trainX_market shape: (38, 2, 1)
# RNN/CNN testX_market shape: (9, 2, 1)
# MLP trainX_market_mlp shape: (38, 2)
# MLP testX_market_mlp shape: (9, 2)

# %% [markdown]
# ### Inspecting the tensors

# %% [markdown]
# Shape & window 0 values

# %%
print("trainX_market shape:", trainX_market.shape)

window_id = 0

market_ma.iloc[
    window_id : window_id + look_back + 1
][["saledate", "MA"]]
# Out:
# trainX_market shape: (38, 2, 1)
#     saledate             MA
# 0 2007-03-31  485130.000000
# 1 2007-06-30  446359.000000
# 2 2007-09-30  505957.666667

# %% [markdown]
# Scale window 0

# %%
# Visualize one input window and its target

window_id = 0

print("Input window:")
print(trainX_market[window_id].flatten())

print("Target:")
print(trainY_market[window_id])
# Out:
# Input window:
# [0.22095731 0.        ]
# Target:
# 0.33965492068299463

# %% [markdown]
# ### Market-level RNN model & evaluation

# %%
# Build and train market-level RNN model

market_rnn_model = Sequential([
    SimpleRNN(
        16,
        activation="tanh",
        input_shape=(look_back, trainX_market.shape[2])
    ),
    Dense(1)
])

market_rnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_rnn_history = market_rnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.0500 - mean_absolute_error: 0.2169 - val_loss: 0.1204 - val_mean_absolute_error: 0.3453
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0223 - mean_absolute_error: 0.1427 - val_loss: 0.0597 - val_mean_absolute_error: 0.2425
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0068 - mean_absolute_error: 0.0768 - val_loss: 0.0229 - val_mean_absolute_error: 0.1492
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0272 - val_loss: 0.0061 - val_mean_absolute_error: 0.0754
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0423 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0049 - mean_absolute_error: 0.0608 - val_loss: 6.6128e-04 - val_mean_absolute_error: 0.0215
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0052 - mean_absolute_error: 0.0612 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039 - mean_absolute_error: 0.0506 - val_loss: 0.0036 - val_mean_absolute_error: 0.0565
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0077 - val_mean_absolute_error: 0.0849
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0303 - val_loss: 0.0118 - val_mean_absolute_error: 0.1063
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0339 - val_loss: 0.0140 - val_mean_absolute_error: 0.1163
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0350 - val_loss: 0.0138 - val_mean_absolute_error: 0.1150
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0324 - val_loss: 0.0117 - val_mean_absolute_error: 0.1061
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0094 - val_mean_absolute_error: 0.0944
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0076 - val_mean_absolute_error: 0.0846
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0282 - val_loss: 0.0067 - val_mean_absolute_error: 0.0792
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0289 - val_loss: 0.0066 - val_mean_absolute_error: 0.0787
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0285 - val_loss: 0.0070 - val_mean_absolute_error: 0.0814
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0279 - val_loss: 0.0077 - val_mean_absolute_error: 0.0851
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0276 - val_loss: 0.0081 - val_mean_absolute_error: 0.0876
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0019 - mean_absolute_error: 0.0275 - val_loss: 0.0082 - val_mean_absolute_error: 0.0881
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 0.0079 - val_mean_absolute_error: 0.0866
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0075 - val_mean_absolute_error: 0.0842
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0071 - val_mean_absolute_error: 0.0818
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0068 - val_mean_absolute_error: 0.0802
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0270 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0268 - val_loss: 0.0067 - val_mean_absolute_error: 0.0796
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0267 - val_loss: 0.0067 - val_mean_absolute_error: 0.0795
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0266 - val_loss: 0.0066 - val_mean_absolute_error: 0.0789
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0064 - val_mean_absolute_error: 0.0780
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0265 - val_loss: 0.0063 - val_mean_absolute_error: 0.0770
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0062 - val_mean_absolute_error: 0.0762
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0264 - val_loss: 0.0061 - val_mean_absolute_error: 0.0756
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0263 - val_loss: 0.0060 - val_mean_absolute_error: 0.0751
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0748
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0059 - val_mean_absolute_error: 0.0743
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0058 - val_mean_absolute_error: 0.0738
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0018 - mean_absolute_error: 0.0261 - val_loss: 0.0057 - val_mean_absolute_error: 0.0732
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0056 - val_mean_absolute_error: 0.0727
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0055 - val_mean_absolute_error: 0.0721
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0055 - val_mean_absolute_error: 0.0717
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0054 - val_mean_absolute_error: 0.0713
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0258 - val_loss: 0.0053 - val_mean_absolute_error: 0.0709
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0053 - val_mean_absolute_error: 0.0705
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0052 - val_mean_absolute_error: 0.0701
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 0.0051 - val_mean_absolute_error: 0.0696
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0051 - val_mean_absolute_error: 0.0693
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 0.0050 - val_mean_absolute_error: 0.0689
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0050 - val_mean_absolute_error: 0.0685
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0682
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0255 - val_loss: 0.0049 - val_mean_absolute_error: 0.0679
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0673
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0254 - val_loss: 0.0048 - val_mean_absolute_error: 0.0670
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0047 - val_mean_absolute_error: 0.0664
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0046 - val_mean_absolute_error: 0.0662
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0659
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0046 - val_mean_absolute_error: 0.0657
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0654
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0045 - val_mean_absolute_error: 0.0652
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0650
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0045 - val_mean_absolute_error: 0.0648
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0646
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 0.0044 - val_mean_absolute_error: 0.0644
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0642
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0044 - val_mean_absolute_error: 0.0640
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0639
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0043 - val_mean_absolute_error: 0.0637
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0635
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0043 - val_mean_absolute_error: 0.0634
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0632
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0631
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0628
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0627
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0042 - val_mean_absolute_error: 0.0625
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0624
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0248 - val_loss: 0.0041 - val_mean_absolute_error: 0.0623
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0621
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0619
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0618
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0041 - val_mean_absolute_error: 0.0617
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0247 - val_loss: 0.0040 - val_mean_absolute_error: 0.0616
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0615
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0613
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0612
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0040 - val_mean_absolute_error: 0.0611
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0040 - val_mean_absolute_error: 0.0610
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0609
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0608
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0607
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0606
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0039 - val_mean_absolute_error: 0.0605
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0244 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604

# %% [markdown]
# Training curves

# %%
plot_training_curves(
    market_rnn_history,
    "Market-level RNN"
)

# %% [markdown]
# Test data evaluation

# %%
evaluate_and_plot(
    market_rnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level RNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Market-level RNN Train RMSE: 8131.16
# Market-level RNN Test RMSE: 15985.01

# %% [markdown]
# ### Market level MLP and evaluation

# %%
# Build and train market-level MLP model

market_mlp_model = Sequential([
    Dense(
        32,
        activation="relu",
        input_shape=(trainX_market_mlp.shape[1],)
    ),
    Dense(
        16,
        activation="relu"
    ),
    Dense(1)
])

market_mlp_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_mlp_history = market_mlp_model.fit(
    trainX_market_mlp,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0963 - mean_absolute_error: 0.2989 - val_loss: 0.2720 - val_mean_absolute_error: 0.5195
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0762 - mean_absolute_error: 0.2646 - val_loss: 0.2254 - val_mean_absolute_error: 0.4728
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0604 - mean_absolute_error: 0.2341 - val_loss: 0.1870 - val_mean_absolute_error: 0.4305
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0456 - mean_absolute_error: 0.2016 - val_loss: 0.1498 - val_mean_absolute_error: 0.3851
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0322 - mean_absolute_error: 0.1670 - val_loss: 0.1146 - val_mean_absolute_error: 0.3366
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0213 - mean_absolute_error: 0.1330 - val_loss: 0.0845 - val_mean_absolute_error: 0.2888
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0130 - mean_absolute_error: 0.1011 - val_loss: 0.0601 - val_mean_absolute_error: 0.2432
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - mean_absolute_error: 0.0734 - val_loss: 0.0413 - val_mean_absolute_error: 0.2013
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - mean_absolute_error: 0.0562 - val_loss: 0.0279 - val_mean_absolute_error: 0.1649
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0446 - val_loss: 0.0189 - val_mean_absolute_error: 0.1352
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - mean_absolute_error: 0.0378 - val_loss: 0.0133 - val_mean_absolute_error: 0.1128
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mean_absolute_error: 0.0375 - val_loss: 0.0101 - val_mean_absolute_error: 0.0979
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mean_absolute_error: 0.0413 - val_loss: 0.0086 - val_mean_absolute_error: 0.0901
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0033 - mean_absolute_error: 0.0434 - val_loss: 0.0083 - val_mean_absolute_error: 0.0883
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0033 - mean_absolute_error: 0.0432 - val_loss: 0.0087 - val_mean_absolute_error: 0.0908
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mean_absolute_error: 0.0416 - val_loss: 0.0097 - val_mean_absolute_error: 0.0958
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0029 - mean_absolute_error: 0.0396 - val_loss: 0.0109 - val_mean_absolute_error: 0.1018
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0121 - val_mean_absolute_error: 0.1076
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - mean_absolute_error: 0.0378 - val_loss: 0.0131 - val_mean_absolute_error: 0.1123
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0025 - mean_absolute_error: 0.0379 - val_loss: 0.0139 - val_mean_absolute_error: 0.1155
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - mean_absolute_error: 0.0377 - val_loss: 0.0143 - val_mean_absolute_error: 0.1172
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0024 - mean_absolute_error: 0.0375 - val_loss: 0.0143 - val_mean_absolute_error: 0.1174
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - mean_absolute_error: 0.0371 - val_loss: 0.0141 - val_mean_absolute_error: 0.1165
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023 - mean_absolute_error: 0.0365 - val_loss: 0.0137 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0359 - val_loss: 0.0133 - val_mean_absolute_error: 0.1131
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0129 - val_mean_absolute_error: 0.1111
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0348 - val_loss: 0.0125 - val_mean_absolute_error: 0.1094
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0121 - val_mean_absolute_error: 0.1079
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - val_loss: 0.0119 - val_mean_absolute_error: 0.1068
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0334 - val_loss: 0.0117 - val_mean_absolute_error: 0.1059
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0330 - val_loss: 0.0115 - val_mean_absolute_error: 0.1051
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0326 - val_loss: 0.0114 - val_mean_absolute_error: 0.1045
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0112 - val_mean_absolute_error: 0.1039
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0111 - val_mean_absolute_error: 0.1033
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0113 - val_mean_absolute_error: 0.1042
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mean_absolute_error: 0.0306 - val_loss: 0.0106 - val_mean_absolute_error: 0.1010
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0293 - val_loss: 0.0102 - val_mean_absolute_error: 0.0988
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mean_absolute_error: 0.0287 - val_loss: 0.0099 - val_mean_absolute_error: 0.0973
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0280 - val_loss: 0.0096 - val_mean_absolute_error: 0.0960
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0275 - val_loss: 0.0094 - val_mean_absolute_error: 0.0947
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0266 - val_loss: 0.0091 - val_mean_absolute_error: 0.0932
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0258 - val_loss: 0.0088 - val_mean_absolute_error: 0.0916
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 0.0085 - val_mean_absolute_error: 0.0901
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0082 - val_mean_absolute_error: 0.0885
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0013 - mean_absolute_error: 0.0244 - val_loss: 0.0079 - val_mean_absolute_error: 0.0868
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0239 - val_loss: 0.0076 - val_mean_absolute_error: 0.0852
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 0.0073 - val_mean_absolute_error: 0.0834
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 0.0070 - val_mean_absolute_error: 0.0818
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0068 - val_mean_absolute_error: 0.0803
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0222 - val_loss: 0.0066 - val_mean_absolute_error: 0.0790
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0218 - val_loss: 0.0064 - val_mean_absolute_error: 0.0778
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0010 - mean_absolute_error: 0.0214 - val_loss: 0.0062 - val_mean_absolute_error: 0.0766
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.9056e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0060 - val_mean_absolute_error: 0.0755
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.6462e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0058 - val_mean_absolute_error: 0.0745
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.3160e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0057 - val_mean_absolute_error: 0.0735
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0640e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0056 - val_mean_absolute_error: 0.0726
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.8084e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0054 - val_mean_absolute_error: 0.0717
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.5669e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0053 - val_mean_absolute_error: 0.0708
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2883e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0051 - val_mean_absolute_error: 0.0697
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0884e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0050 - val_mean_absolute_error: 0.0686
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.8618e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0048 - val_mean_absolute_error: 0.0676
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.7107e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0047 - val_mean_absolute_error: 0.0667
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.4770e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0046 - val_mean_absolute_error: 0.0656
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.2799e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0044 - val_mean_absolute_error: 0.0645
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.1166e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0043 - val_mean_absolute_error: 0.0636
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.9992e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0042 - val_mean_absolute_error: 0.0629
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.8212e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0041 - val_mean_absolute_error: 0.0622
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.6454e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0040 - val_mean_absolute_error: 0.0614
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4761e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0039 - val_mean_absolute_error: 0.0604
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.3571e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0038 - val_mean_absolute_error: 0.0595
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.2080e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0037 - val_mean_absolute_error: 0.0587
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.0849e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0036 - val_mean_absolute_error: 0.0579
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.9526e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0035 - val_mean_absolute_error: 0.0571
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.8087e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0034 - val_mean_absolute_error: 0.0562
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7122e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0033 - val_mean_absolute_error: 0.0552
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.5897e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0032 - val_mean_absolute_error: 0.0544
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4827e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0031 - val_mean_absolute_error: 0.0537
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.3872e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0030 - val_mean_absolute_error: 0.0531
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2766e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0029 - val_mean_absolute_error: 0.0524
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.1636e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0029 - val_mean_absolute_error: 0.0518
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0725e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0028 - val_mean_absolute_error: 0.0513
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.9774e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0028 - val_mean_absolute_error: 0.0508
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8932e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0027 - val_mean_absolute_error: 0.0505
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.7916e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0027 - val_mean_absolute_error: 0.0500
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.6910e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0026 - val_mean_absolute_error: 0.0494
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6119e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0026 - val_mean_absolute_error: 0.0488
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 4.5516e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0025 - val_mean_absolute_error: 0.0484
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.4546e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0025 - val_mean_absolute_error: 0.0480
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.3622e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0024 - val_mean_absolute_error: 0.0475
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2781e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0469
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2065e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0023 - val_mean_absolute_error: 0.0466
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 4.1327e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0023 - val_mean_absolute_error: 0.0462
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.0575e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0023 - val_mean_absolute_error: 0.0457
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.9766e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0451
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9181e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0022 - val_mean_absolute_error: 0.0446
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8662e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0442
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7958e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0021 - val_mean_absolute_error: 0.0438
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.7290e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0020 - val_mean_absolute_error: 0.0434
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6603e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0020 - val_mean_absolute_error: 0.0430
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6022e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0020 - val_mean_absolute_error: 0.0428

# %% [markdown]
# Training curves MLP

# %%
plot_training_curves(
    market_mlp_history,
    "Market-level MLP"
)

# %% [markdown]
# Test data evaluation MLP

# %%
evaluate_and_plot(
    market_mlp_model,
    trainX_market_mlp,
    testX_market_mlp,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level MLP"
)
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3111ce7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/stepWARNING:tensorflow:6 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3111ce7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Market-level MLP Train RMSE: 4631.41
# Market-level MLP Test RMSE: 10526.73

# %% [markdown]
# ### Market level CNN & evaluation

# %%
# Build and train market-level 1D CNN model

market_cnn_model = Sequential([
    Conv1D(
        filters=16,                         # learn 16 temporal pattern detectors
        kernel_size=2,                      # each filter looks across 2 neighboring timesteps
        activation="relu",
        input_shape=(look_back, trainX_market.shape[2])
    ),                                      # input shape = timesteps, features

    Flatten(),                              # convert CNN output to flat vector for Dense layer

    Dense(1)                                # regression output layer
])

market_cnn_model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

market_cnn_history = market_cnn_model.fit(
    trainX_market,
    trainY_market,
    epochs=100,
    batch_size=8,
    validation_split=0.2,
    shuffle=False,                          # preserve temporal order
    verbose=1
)
# Out:
# Epoch 1/100
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0999 - mean_absolute_error: 0.3029 - val_loss: 0.2975 - val_mean_absolute_error: 0.5433
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0884 - mean_absolute_error: 0.2840 - val_loss: 0.2710 - val_mean_absolute_error: 0.5184
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0778 - mean_absolute_error: 0.2656 - val_loss: 0.2458 - val_mean_absolute_error: 0.4937
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0681 - mean_absolute_error: 0.2474 - val_loss: 0.2222 - val_mean_absolute_error: 0.4693
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0592 - mean_absolute_error: 0.2297 - val_loss: 0.2003 - val_mean_absolute_error: 0.4455
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0514 - mean_absolute_error: 0.2127 - val_loss: 0.1801 - val_mean_absolute_error: 0.4224
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0445 - mean_absolute_error: 0.1967 - val_loss: 0.1618 - val_mean_absolute_error: 0.4001
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0385 - mean_absolute_error: 0.1815 - val_loss: 0.1457 - val_mean_absolute_error: 0.3796
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0332 - mean_absolute_error: 0.1671 - val_loss: 0.1313 - val_mean_absolute_error: 0.3604
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0285 - mean_absolute_error: 0.1539 - val_loss: 0.1183 - val_mean_absolute_error: 0.3420
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0244 - mean_absolute_error: 0.1411 - val_loss: 0.1065 - val_mean_absolute_error: 0.3243
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0207 - mean_absolute_error: 0.1289 - val_loss: 0.0958 - val_mean_absolute_error: 0.3074
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0176 - mean_absolute_error: 0.1172 - val_loss: 0.0860 - val_mean_absolute_error: 0.2912
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0149 - mean_absolute_error: 0.1069 - val_loss: 0.0773 - val_mean_absolute_error: 0.2759
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0126 - mean_absolute_error: 0.0976 - val_loss: 0.0694 - val_mean_absolute_error: 0.2614
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0107 - mean_absolute_error: 0.0889 - val_loss: 0.0624 - val_mean_absolute_error: 0.2477
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0090 - mean_absolute_error: 0.0810 - val_loss: 0.0562 - val_mean_absolute_error: 0.2349
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0077 - mean_absolute_error: 0.0749 - val_loss: 0.0507 - val_mean_absolute_error: 0.2230
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0066 - mean_absolute_error: 0.0702 - val_loss: 0.0459 - val_mean_absolute_error: 0.2119
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0058 - mean_absolute_error: 0.0659 - val_loss: 0.0416 - val_mean_absolute_error: 0.2017
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051 - mean_absolute_error: 0.0623 - val_loss: 0.0379 - val_mean_absolute_error: 0.1924
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0045 - mean_absolute_error: 0.0590 - val_loss: 0.0347 - val_mean_absolute_error: 0.1840
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0041 - mean_absolute_error: 0.0561 - val_loss: 0.0319 - val_mean_absolute_error: 0.1763
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0038 - mean_absolute_error: 0.0535 - val_loss: 0.0295 - val_mean_absolute_error: 0.1694
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0036 - mean_absolute_error: 0.0511 - val_loss: 0.0275 - val_mean_absolute_error: 0.1633
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0034 - mean_absolute_error: 0.0491 - val_loss: 0.0257 - val_mean_absolute_error: 0.1579
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0033 - mean_absolute_error: 0.0475 - val_loss: 0.0242 - val_mean_absolute_error: 0.1531
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0032 - mean_absolute_error: 0.0460 - val_loss: 0.0230 - val_mean_absolute_error: 0.1490
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mean_absolute_error: 0.0449 - val_loss: 0.0219 - val_mean_absolute_error: 0.1453
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0210 - val_mean_absolute_error: 0.1422
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mean_absolute_error: 0.0432 - val_loss: 0.0202 - val_mean_absolute_error: 0.1395
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mean_absolute_error: 0.0426 - val_loss: 0.0195 - val_mean_absolute_error: 0.1371
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030 - mean_absolute_error: 0.0420 - val_loss: 0.0190 - val_mean_absolute_error: 0.1351
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0030 - mean_absolute_error: 0.0416 - val_loss: 0.0185 - val_mean_absolute_error: 0.1334
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0412 - val_loss: 0.0181 - val_mean_absolute_error: 0.1320
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0408 - val_loss: 0.0178 - val_mean_absolute_error: 0.1308
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0175 - val_mean_absolute_error: 0.1298
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - mean_absolute_error: 0.0401 - val_loss: 0.0174 - val_mean_absolute_error: 0.1291
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0398 - val_loss: 0.0171 - val_mean_absolute_error: 0.1281
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028 - mean_absolute_error: 0.0395 - val_loss: 0.0168 - val_mean_absolute_error: 0.1271
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - mean_absolute_error: 0.0392 - val_loss: 0.0166 - val_mean_absolute_error: 0.1262
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0390 - val_loss: 0.0164 - val_mean_absolute_error: 0.1255
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mean_absolute_error: 0.0388 - val_loss: 0.0163 - val_mean_absolute_error: 0.1249
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0028 - mean_absolute_error: 0.0386 - val_loss: 0.0161 - val_mean_absolute_error: 0.1243
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mean_absolute_error: 0.0384 - val_loss: 0.0160 - val_mean_absolute_error: 0.1238
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0027 - mean_absolute_error: 0.0382 - val_loss: 0.0159 - val_mean_absolute_error: 0.1233
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0027 - mean_absolute_error: 0.0379 - val_loss: 0.0157 - val_mean_absolute_error: 0.1228
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0027 - mean_absolute_error: 0.0377 - val_loss: 0.0156 - val_mean_absolute_error: 0.1223
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0027 - mean_absolute_error: 0.0376 - val_loss: 0.0155 - val_mean_absolute_error: 0.1218
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0373 - val_loss: 0.0154 - val_mean_absolute_error: 0.1213
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0026 - mean_absolute_error: 0.0371 - val_loss: 0.0153 - val_mean_absolute_error: 0.1208
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0026 - mean_absolute_error: 0.0370 - val_loss: 0.0151 - val_mean_absolute_error: 0.1204
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0026 - mean_absolute_error: 0.0368 - val_loss: 0.0150 - val_mean_absolute_error: 0.1199
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0026 - mean_absolute_error: 0.0366 - val_loss: 0.0149 - val_mean_absolute_error: 0.1194
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0026 - mean_absolute_error: 0.0364 - val_loss: 0.0148 - val_mean_absolute_error: 0.1190
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0025 - mean_absolute_error: 0.0362 - val_loss: 0.0147 - val_mean_absolute_error: 0.1185
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0025 - mean_absolute_error: 0.0360 - val_loss: 0.0146 - val_mean_absolute_error: 0.1180
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0025 - mean_absolute_error: 0.0358 - val_loss: 0.0144 - val_mean_absolute_error: 0.1175
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0025 - mean_absolute_error: 0.0357 - val_loss: 0.0143 - val_mean_absolute_error: 0.1171
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0025 - mean_absolute_error: 0.0355 - val_loss: 0.0142 - val_mean_absolute_error: 0.1166
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0025 - mean_absolute_error: 0.0353 - val_loss: 0.0141 - val_mean_absolute_error: 0.1161
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0025 - mean_absolute_error: 0.0351 - val_loss: 0.0140 - val_mean_absolute_error: 0.1157
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0024 - mean_absolute_error: 0.0349 - val_loss: 0.0139 - val_mean_absolute_error: 0.1152
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0024 - mean_absolute_error: 0.0348 - val_loss: 0.0138 - val_mean_absolute_error: 0.1147
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0024 - mean_absolute_error: 0.0346 - val_loss: 0.0137 - val_mean_absolute_error: 0.1143
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0136 - val_mean_absolute_error: 0.1138
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0024 - mean_absolute_error: 0.0342 - val_loss: 0.0135 - val_mean_absolute_error: 0.1134
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0024 - mean_absolute_error: 0.0340 - val_loss: 0.0133 - val_mean_absolute_error: 0.1129
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0024 - mean_absolute_error: 0.0339 - val_loss: 0.0133 - val_mean_absolute_error: 0.1125
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0023 - mean_absolute_error: 0.0337 - val_loss: 0.0132 - val_mean_absolute_error: 0.1121
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0131 - val_mean_absolute_error: 0.1117
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0023 - mean_absolute_error: 0.0333 - val_loss: 0.0130 - val_mean_absolute_error: 0.1113
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0023 - mean_absolute_error: 0.0332 - val_loss: 0.0129 - val_mean_absolute_error: 0.1109
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - mean_absolute_error: 0.0330 - val_loss: 0.0128 - val_mean_absolute_error: 0.1105
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - mean_absolute_error: 0.0328 - val_loss: 0.0127 - val_mean_absolute_error: 0.1101
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.0126 - val_mean_absolute_error: 0.1097
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - mean_absolute_error: 0.0325 - val_loss: 0.0125 - val_mean_absolute_error: 0.1093
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - val_loss: 0.0124 - val_mean_absolute_error: 0.1089
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0022 - mean_absolute_error: 0.0322 - val_loss: 0.0124 - val_mean_absolute_error: 0.1085
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0022 - mean_absolute_error: 0.0320 - val_loss: 0.0123 - val_mean_absolute_error: 0.1082
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0022 - mean_absolute_error: 0.0319 - val_loss: 0.0122 - val_mean_absolute_error: 0.1078
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0317 - val_loss: 0.0121 - val_mean_absolute_error: 0.1074
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0022 - mean_absolute_error: 0.0315 - val_loss: 0.0120 - val_mean_absolute_error: 0.1070
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0022 - mean_absolute_error: 0.0314 - val_loss: 0.0119 - val_mean_absolute_error: 0.1066
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0021 - mean_absolute_error: 0.0312 - val_loss: 0.0119 - val_mean_absolute_error: 0.1063
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0310 - val_loss: 0.0118 - val_mean_absolute_error: 0.1059
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0308 - val_loss: 0.0117 - val_mean_absolute_error: 0.1055
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0307 - val_loss: 0.0116 - val_mean_absolute_error: 0.1052
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0116 - val_mean_absolute_error: 0.1048
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0303 - val_loss: 0.0115 - val_mean_absolute_error: 0.1045
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0021 - mean_absolute_error: 0.0302 - val_loss: 0.0114 - val_mean_absolute_error: 0.1042
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0113 - val_mean_absolute_error: 0.1039
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mean_absolute_error: 0.0299 - val_loss: 0.0113 - val_mean_absolute_error: 0.1035
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0112 - val_mean_absolute_error: 0.1032
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0296 - val_loss: 0.0111 - val_mean_absolute_error: 0.1029
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0294 - val_loss: 0.0111 - val_mean_absolute_error: 0.1025
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0110 - val_mean_absolute_error: 0.1022
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0292 - val_loss: 0.0109 - val_mean_absolute_error: 0.1019
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0109 - val_mean_absolute_error: 0.1016
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0290 - val_loss: 0.0108 - val_mean_absolute_error: 0.1013

# %% [markdown]
# Training curves 1D CNN

# %%
plot_training_curves(
    market_cnn_history,
    "Market-level 1D CNN"
)

# %% [markdown]
# Test data evaluation 1D CNN

# %%
evaluate_and_plot(
    market_cnn_model,
    trainX_market,
    testX_market,
    trainY_market,
    testY_market,
    scaler_market,
    "Market-level 1D CNN"
)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Market-level 1D CNN Train RMSE: 10858.94
# Market-level 1D CNN Test RMSE: 27010.29

# %% [markdown]
# ### Comparison of RNN vs MLP vs 1D CNN

# %%
rnn_rmse, rnn_mae = evaluate_metrics(
    market_rnn_model,
    testX_market,
    testY_market,
    scaler_market
)

mlp_rmse, mlp_mae = evaluate_metrics(
    market_mlp_model,
    testX_market_mlp,
    testY_market,
    scaler_market
)

cnn_rmse, cnn_mae = evaluate_metrics(
    market_cnn_model,
    testX_market,
    testY_market,
    scaler_market
)

comparison = pd.DataFrame({
    "Model": ["RNN", "MLP", "1D CNN"],
    "RMSE": [rnn_rmse, mlp_rmse, cnn_rmse],
    "MAE": [rnn_mae, mlp_mae, cnn_mae]
})

comparison
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#     Model          RMSE           MAE
# 0     RNN  15985.008451  15295.126984
# 1     MLP  10526.726267   9675.571429
# 2  1D CNN  27010.288619  26676.696429

# %% [markdown]
# ### Your Turn — Build and Compare RNN Models
#
# Choose one or more coherent housing subgroups (for example, 3-bedroom houses) and build at least 3 meaningfully different RNN forecasting models. Evaluate each model using training/validation curves, held-out future test predictions, RMSE, and MAE, and record your observations in markdown cells throughout the notebook.

# %% [markdown]
# ### Model Exploration Summary
#
# Briefly summarize which subgroup(s) and model variations you explored, what changes appeared to improve or worsen forecasting performance, any patterns you noticed in the training curves or predictions, and which model you believe performed best and why.

# %% [markdown]
# - **Subgroup explored:** 3-bedroom houses (`type == "house"`, `bedrooms == 3`)
# - **Model variations:** (1) look_back=2, 16 units — (2) look_back=4, 32 units — (3) look_back=2, 32 units + dropout 0.2
# - **What improved performance:** *(compare RMSE/MAE table and prediction plots)*
# - **Tradeoffs:** *(e.g. longer lookback needs more data; dropout slowed overfitting but …)*
# - **Best model:** *(name + why — lowest test RMSE/MAE with stable val curves)*

# %%
# Subgroup: 3-bedroom houses (one coherent quarterly MA series)
subgroup = (
    house[(house["type"] == "house") & (house["bedrooms"] == 3)]
    .sort_values("saledate")
    .reset_index(drop=True)
)
print(f"Subgroup: 3-bedroom houses | rows: {len(subgroup)}")


def fit_subgroup_rnn(name, look_back, rnn_units, dropout_rate=0.0, epochs=100):
    """Train a SimpleRNN forecaster on the subgroup; return metrics and artifacts."""
    tf.keras.backend.clear_session()
    tf.random.set_seed(42)

    df = subgroup[["MA"]].copy()
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(df)

    train_size = int(len(scaled) * 0.8)
    train_s, test_s = scaled[:train_size], scaled[train_size:]

    trainX, trainY = create_sequences(train_s, look_back)
    testX, testY = create_sequences(test_s, look_back)

    layers_list = [
        SimpleRNN(rnn_units, activation="tanh", input_shape=(look_back, 1)),
    ]
    if dropout_rate:
        layers_list.append(Dropout(dropout_rate))
    layers_list.append(Dense(1))

    model = Sequential(layers_list)
    model.compile(optimizer="adam", loss="mean_squared_error", metrics=["mean_absolute_error"])

    history = model.fit(
        trainX, trainY,
        epochs=epochs,
        batch_size=8,
        validation_split=0.2,
        shuffle=False,
        verbose=0,
    )

    rmse, mae = evaluate_metrics(model, testX, testY, scaler)
    print(f"{name}: test RMSE={rmse:,.0f}  MAE={mae:,.0f}")

    return {
        "name": name,
        "look_back": look_back,
        "units": rnn_units,
        "dropout": dropout_rate,
        "history": history,
        "model": model,
        "rmse": rmse,
        "mae": mae,
        "trainX": trainX,
        "testX": testX,
        "trainY": trainY,
        "testY": testY,
        "scaler": scaler,
    }


# Three meaningfully different RNN configs
exp_results = []
exp_results.append(fit_subgroup_rnn("RNN_lb2_u16", look_back=2, rnn_units=16))
exp_results.append(fit_subgroup_rnn("RNN_lb4_u32", look_back=4, rnn_units=32))
exp_results.append(fit_subgroup_rnn("RNN_lb2_u32_drop", look_back=2, rnn_units=32, dropout_rate=0.2))
# Out:
# Subgroup: 3-bedroom houses | rows: 51
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# RNN_lb2_u16: test RMSE=24,013  MAE=23,999
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# RNN_lb4_u32: test RMSE=51,150  MAE=51,118
# /Users/mkenne16/Documents/Advanced Machine Learning/week 7/.venv/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# RNN_lb2_u32_drop: test RMSE=5,425  MAE=3,776

# %%
# Compare experiment models (RMSE / MAE on held-out test)
exp_comparison = pd.DataFrame([
    {
        "Model": r["name"],
        "look_back": r["look_back"],
        "units": r["units"],
        "dropout": r["dropout"],
        "test_RMSE": round(r["rmse"], 2),
        "test_MAE": round(r["mae"], 2),
    }
    for r in exp_results
])
exp_comparison
# Out:
#               Model  look_back  units  dropout  test_RMSE  test_MAE
# 0       RNN_lb2_u16          2     16      0.0   24012.80  23999.35
# 1       RNN_lb4_u32          4     32      0.0   51149.69  51118.46
# 2  RNN_lb2_u32_drop          2     32      0.2    5425.01   3775.84

# %%
# Training curves for each experiment model
for r in exp_results:
    plot_training_curves(r["history"], r["name"])

# Held-out test prediction plots
for r in exp_results:
    evaluate_and_plot(
        r["model"],
        r["trainX"],
        r["testX"],
        r["trainY"],
        r["testY"],
        r["scaler"],
        r["name"],
    )
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# RNN_lb2_u16 Train RMSE: 6229.28
# RNN_lb2_u16 Test RMSE: 24012.80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# RNN_lb4_u32 Train RMSE: 12519.16
# RNN_lb4_u32 Test RMSE: 51149.69
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# RNN_lb2_u32_drop Train RMSE: 7102.32
# RNN_lb2_u32_drop Test RMSE: 5425.01
